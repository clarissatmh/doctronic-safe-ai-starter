# %%
answer = 22
    print(answer)
guess = int(input("what is your guess?"))
#need to store this input that's why add guess = int ....
if guess == answer:
    print("you got it right")
elif guess < answer:
    print("your guess is too low try again")
else:
    print("your guess is too high try again")
# one = sign is assigning, two = sign is checking.
#after this we need to put this intoa loop. there is a while loopr or a for loop.

# %%
x = 1
while (x < 10):
    print(x)
    x += 1
    # this is shortform of x = x + 1. so it loops the number until it reaches 10.

# %%
answer = 22
print(answer)
is_user_wrong = True

while is_user_wrong:
    guess = int(input("what is your guess?"))
    
    if guess == answer:
        print("you got it right")
        is_user_wrong = False
    elif guess < answer:
        print("your guess is too low try again")
    else:
        print("your guess is too high try again")
# Out:
# 22
# your guess is too high try again
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 6
#       2 print(answer)
#       3 is_user_wrong = True
#       4
#       5 while is_user_wrong:
# ----> 6     guess = int(input("what is your guess?"))
#       7
#       8     if guess == answer:
#       9         print("you got it right")
#
# ValueError: invalid literal for int() with base 10: ''
